# %%
import pandas as pd
import numpy as np

# %%
damage = pd.read_csv("ukr_damage.csv", delimiter="|")
damage.head()
# Out:
#   damage_id iso3  country         gid_1    oblast              rayon  \
# 0     D0011  UKR  Ukraine  ['UKR.15_1']  Luhanska  Siverskodonetskyi
# 1     D0012  UKR  Ukraine  ['UKR.15_1']  Luhanska  Siverskodonetskyi
# 2     D0015  UKR  Ukraine  ['UKR.14_1']   Lvivska                NaN
# 3     D0016  UKR  Ukraine  ['UKR.14_1']   Lvivska                NaN
# 4     D0017  UKR  Ukraine  ['UKR.12_1']   Kyivska                NaN
#
#   type_of_infrastructure         if_other_what date_of_event source_name  \
# 0              Warehouse                   NaN    2022-03-25        OCHA
# 1              Warehouse                   NaN    2022-03-26        OCHA
# 2              Warehouse                   NaN    2022-03-26        OCHA
# 3  Aircraft repair plant  Aircraft repair plan    2022-03-26        OCHA
# 4                 Bridge                   NaN    2022-03-22        OCHA
#
#   source_date                                        source_link  \
# 0  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 1  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 2  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 3  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 4  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
#
#   additional_sources   extent_of_damage _internal_filter_date  _weights  \
# 0                NaN          Destroyed            2022-03-25       0.7
# 1                NaN  Partially damaged            2022-03-26       0.7
# 2                NaN            Unknown            2022-03-26       1.0
# 3                NaN          Destroyed            2022-03-26       1.0
# 4                NaN          Destroyed            2022-03-22       1.0
#
#   access_subindicator pcode
# 0             ['7.2']  UA44
# 1             ['7.2']  UA44
# 2             ['7.2']  UA46
# 3             ['7.2']  UA46
# 4             ['9.2']  UA32

# %%
ukr_damages = pd.read_csv("ukraine-damages.csv", delimiter = "|")
ukr_damages.head()
# Out:
#   damage_id iso3  country         gid_1    oblast              rayon  \
# 0     D0011  UKR  Ukraine  ['UKR.15_1']  Luhanska  Siverskodonetskyi
# 1     D0012  UKR  Ukraine  ['UKR.15_1']  Luhanska  Siverskodonetskyi
# 2     D0015  UKR  Ukraine  ['UKR.14_1']   Lvivska                NaN
# 3     D0016  UKR  Ukraine  ['UKR.14_1']   Lvivska                NaN
# 4     D0017  UKR  Ukraine  ['UKR.12_1']   Kyivska                NaN
#
#   type_of_infrastructure         if_other_what date_of_event source_name  \
# 0              Warehouse                   NaN    2022-03-25        OCHA
# 1              Warehouse                   NaN    2022-03-26        OCHA
# 2              Warehouse                   NaN    2022-03-26        OCHA
# 3  Aircraft repair plant  Aircraft repair plan    2022-03-26        OCHA
# 4                 Bridge                   NaN    2022-03-22        OCHA
#
#   source_date                                        source_link  \
# 0  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 1  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 2  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 3  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
# 4  2022-03-28  https://reliefweb.int/report/ukraine/ukraine-h...
#
#   additional_sources   extent_of_damage _internal_filter_date  _weights  \
# 0                NaN          Destroyed            2022-03-25       0.7
# 1                NaN  Partially damaged            2022-03-26       0.7
# 2                NaN            Unknown            2022-03-26       1.0
# 3                NaN          Destroyed            2022-03-26       1.0
# 4                NaN          Destroyed            2022-03-22       1.0
#
#   access_subindicator pcode
# 0             ['7.2']  UA44
# 1             ['7.2']  UA44
# 2             ['7.2']  UA46
# 3             ['7.2']  UA46
# 4             ['9.2']  UA32

# %%
ukr_damages.shape
# Out:
# (24269, 18)

# %%
damage.shape
# Out:
# (24269, 18)

# %% [markdown]
# _LOOKS LIKE THE TWO DATASETS ARE THE SAME.  SAME SHAPE, SAME COLUMNS._

# %%
ukr_damages.columns
# Out:
# Index(['damage_id', 'iso3', 'country', 'gid_1', 'oblast', 'rayon',
#        'type_of_infrastructure', 'if_other_what', 'date_of_event',
#        'source_name', 'source_date', 'source_link', 'additional_sources',
#        'extent_of_damage', '_internal_filter_date', '_weights',
#        'access_subindicator', 'pcode'],
#       dtype='object')

# %%
"""
    'damage_id',                >> primary key, identifies a given instance of damage upon infrastructure
    'iso3',                     >> Three-digit International Standards Organization (ISO) country code.  Only one value, "UKR", in all 
                                        24269 rows--all data is for Ukraine/UKR  Categorical string.
    'country',                  >> Same situation as 'iso3', "Ukraine" in all 24269 rows.  Country in which the infrastructure was damaged.
    'gid_1',                    >> Not sure what "gid" is, but the value counts for this and "oblast" appear to correlate--would want to see on a
                                        correlation matrix/heat map.  One could infer it loosely breaks out to "geographic identifier."
                                        Based on this, we assess it to be a categorical string.
    'oblast',                   >> An "oblast" is the primary administrative division of Ukraine, loosely translated to "region"/"province".
                                        The individual values correlate to the (24 oblasts + 2 cities with special status + 1 autonomous republic)
                                        identified/recognized as comprising Ukraine.  Categorical string.
    'rayon',                    >> A "rayon" is the secondary administrative division of Ukraine, i.e., an oblast is subdivided into 
                                        rayons. Essentially "districts."  Categorical string.
    'type_of_infrastructure',   >> Categorical description of the infrastructure damaged in the incident  Categorical string.
    'if_other_what',            >> Optional, supplementary field to describe the infrastructure damaged in the incident
                                        if the categories of 'type_of_infrastructure' are insufficient.  Free-entry string.
    'date_of_event',            >> Date upon which the attack happened/the infrastructure was damaged.  Date.
    'source_name',              >> Name of the (primary) source from which the observation was collected.  Free-entry string.
    'source_date',              >> Date upon which the source reported its collection.  Date.
    'source_link',              >> hyperlink at which one can find the reporting.  Free-entry string.
    'additional_sources',       >> (optional) name(s) of sources providing corroborating and/or supplementary information on the event.
                                        Free-entry string.
    'extent_of_damage',         >> categorical, qualitative assessment of the damage done.  Categorical string.
    '_internal_filter_date',    
    '_weights',
    'access_subindicator', 
    'pcode'
"""

# %%
#ukr_damages[['gid_1','oblast']].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ukr_damages[['gid_1','oblast']].corr()
#
# File c:\Users\rdall\miniconda3\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\rdall\miniconda3\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\rdall\miniconda3\Lib\site-packages\pandas\core\internals\managers.py:1688, in BlockManager.as_array(self, dtype, copy, na_value)
#    1686     arr = np.asarray(blk.values, dtype=dtype)
#    1687 else:
# -> 1688     arr = np.array(blk.values, dtype=dtype, copy=copy)
#    1690 if using_copy_on_write() and not copy:
#    1691     arr = arr.view()
#
# ValueError: could not convert string to float: "['UKR.15_1']"

# %%
ukr_damages["iso3"].value_counts()
# Out:
# iso3
# UKR    24269
# Name: count, dtype: int64

# %%
ukr_damages["country"].value_counts()
# Out:
# country
# Ukraine    24269
# Name: count, dtype: int64

# %%
ukr_damages["gid_1"].value_counts()
# Out:
# gid_1
# ['UKR.6_1']     6095
# ['UKR.5_1']     4053
# ['UKR.8_1']     3393
# ['UKR.9_1']     2305
# ['UKR.16_1']    2110
# ['UKR.21_1']    1540
# ['UKR.26_1']     803
# ['UKR.17_1']     671
# ['UKR.12_1']     645
# ['UKR.15_1']     588
# ['UKR.2_1']      516
# ['UKR.11_1']     498
# ['UKR.27_1']     204
# ['UKR.10_1']     177
# ['UKR.18_1']     148
# ['UKR.1_1']      133
# ['UKR.14_1']     128
# ['UKR.13_1']      67
# ['UKR.24_1']      53
# ['UKR.22_1']      37
# ['UKR.19_1']      22
# ['UKR.7_1']       19
# ['UKR.25_1']      16
# ['UKR.4_1']       16
# ['UKR.23_1']      12
# ['UKR.3_1']        7
# ['UKR.20_1']       5
# Name: count, dtype: int64

# %%
ukr_damages["oblast"].value_counts()
# Out:
# oblast
# Donetska                         6095
# Dnipropetrovska                  4053
# Kharkivska                       3393
# Khersonska                       2305
# Mykolaivska                      2110
# Sumska                           1540
# Zaporizka                         803
# Odeska                            671
# Kyivska                           645
# Luhanska                          588
# Chernihivska                      516
# Kyiv                              498
# Zhytomyrska                       204
# Khmelnytska                       177
# Poltavska                         148
# Cherkaska                         133
# Lvivska                           128
# Kirovohradska                      67
# Vinnytska                          53
# Ternopilska                        37
# Rivnenska                          22
# Ivano-Frankivska                   19
# Volynska                           16
# Autonomous Republic of Crimea      16
# Zakarpatska                        12
# Chernivetska                        7
# Sevastopol                          5
# Name: count, dtype: int64

# %%
ukr_damages["rayon"].value_counts()
# Out:
# rayon
# Nikopolskyi     2474
# Kramatorskyi    2274
# Kharkivskyi     1308
# Khersonskyi     1187
# Pokrovskyi       733
#                 ...
# Khmilnytskyi       1
# Yaltynskyi         1
# Zhmerynskyi        1
# Sambirskyi         1
# Kovelskyi          1
# Name: count, Length: 113, dtype: int64

# %%
"""
'type_of_infrastructure',       >> somewhat comprehensive string categorical, 25 bins, appears to have 4x np.nan values
'if_other_what',                >> string box, appears to have 21162x np.nan values, but this would make sense since it's a subcategory.
                                        worth exploring given only 724x "Other" values in 'type_of_infrastructure'
'date_of_event',
'source_name', 
'source_date', 
'source_link', 
'additional_sources',
'extent_of_damage',             >> Straightforward categorical variable
'_internal_filter_date', 
'_weights',
'access_subindicator', 
'pcode'
"""

# %%
ukr_damages["extent_of_damage"].value_counts()
# Out:
# extent_of_damage
# Partially damaged               20566
# Unknown                          2457
# Destroyed                        1242
# Partially damaged, Destroyed        1
# Name: count, dtype: int64

# %%
ukr_damages["type_of_infrastructure"].value_counts()
# Out:
# type_of_infrastructure
# Industrial/Business/Enterprise facilities     5056
# Education facility (school, etc.)             5021
# Electricity supply system                     3016
# Government facilities                         2060
# Gas supply system                             1968
# Cultural facilities (museum, theater etc.)    1210
# Health facility (hospital, health clinic)     1169
# Warehouse                                      834
# Agricultural facilities                        805
# Other                                          724
# Railway                                        556
# Water supply system                            280
# Religious facilities                           277
# Road / Highway                                 245
# Heating and water facility                     244
# Fuel depot                                     203
# Telecommunications                             171
# Bridge                                         146
# Power plant                                     74
# Harbor                                          67
# Chemical storage unit                           53
# Oil depot                                       51
# Airport                                         25
# Nuclear unit                                     7
# Aircraft repair plant                            3
# Name: count, dtype: int64

# %%
ukr_damages["type_of_infrastructure"].isna().sum()
# Out:
# np.int64(4)

# %%
ukr_damages["if_other_what"].value_counts()
# Out:
# if_other_what
# shop                                  96
# retail outlet                         89
# Non-military facilities               82
# Shop                                  51
# trade pavilion                        49
#                                       ..
# football arena                         1
# dairy farm                             1
# student's dormitory                    1
# firefighting and rescue department     1
# hydroelectric station dam              1
# Name: count, Length: 1083, dtype: int64

# %%
ukr_damages["if_other_what"].isna().sum()
# Out:
# np.int64(21162)
